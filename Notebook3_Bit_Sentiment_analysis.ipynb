# %% [markdown]
# ## News Sentiment Analysis and Crypto price prediction

# %% [raw]
# Predict the price trend of Dogecoin and Bitcoin basis their historical prices and News Sentiment analysis. In terms of Machine learning models, we explored CLassification Models as well as Regression models to evaluate which is a more effective methodology.
#
# We have used 4 types of Machine learning models :
#
# Classification Models :
# a) Logistic Regression
# b) Random ForestClassifier
#
# Regression Models :
# a) LSTM RNN - Basis sentiment analysis
# b) XG Boost Model (New model explored)

# %%
## Book 3 : Bitcoin Sentiment Analysis & Merging Sentiment Data with Closing Prices

# %%
# Initial imports
import nltk
import numpy as np
import pandas as pd
from path import Path
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import yfinance as yf
from yahoofinancials import YahooFinancials
from datetime import datetime, date
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Download/Update the VADER Lexicon
nltk.download("vader_lexicon")

# Initialize the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/riteshchugani/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ## Load the News Articles from the CSV File as a DataFrame

# %%
# Load news from CSV file
file_path = Path("bitcoin_news_en_.csv")
news_df = pd.read_csv(file_path, encoding="utf-8-sig")
news_df.head()
# Out:
#                                                title  \
# 0  Netflix is already making a docuseries about t...
# 1  Justice Dept. Announces Raft of Changes Meant ...
# 2  Inside Heather Morgan and Ilya Lichtenstein's ...
# 3  Super Bowl Crypto Ads Feature Larry David, LeB...
# 4  It Only Took 3 Days for Netflix to Order a Doc...
#
#                                          description  \
# 0  Netflix\r\n is making a docuseries about one o...
# 1  The moves came a week after the department mad...
# 2  The arrests of Ilya Lichtenstein and Heather M...
# 3  If Sunday’s Super Bowl ads are any indication,...
# 4  The news of one of the biggest money launderin...
#
#                                                 text        date language
# 0  Netflix\r\n is making a docuseries about one o...  2022-02-11       en
# 1  Even in cyberspace, the Department of Justice ...  2022-02-17       en
# 2  The couple would never flee from the country a...  2022-02-13       en
# 3  If Sundays Super Bowl ads are any indication, ...  2022-02-14       en
# 4  The news of one of the biggest money launderin...  2022-02-12       en

# %%
#Viewing the count of various elements in the data frame
news_df.count()
# Out:
# title          100
# description    100
# text           100
# date           100
# language       100
# dtype: int64

# %%
#show how many articles were written about Bitcoin on a particular day.
daily_data = pd.DataFrame(news_df.groupby('date').count())
daily_data
# Out:
#             title  description  text  language
# date
# 2022-02-10      4            4     4         4
# 2022-02-11      6            6     6         6
# 2022-02-12      3            3     3         3
# 2022-02-13      4            4     4         4
# 2022-02-14      7            7     7         7
# 2022-02-15      7            7     7         7
# 2022-02-16      1            1     1         1
# 2022-02-17      5            5     5         5
# 2022-02-18      5            5     5         5
# 2022-02-19      1            1     1         1
# 2022-02-20      1            1     1         1
# 2022-02-21      1            1     1         1
# 2022-02-22      3            3     3         3
# 2022-02-23      1            1     1         1
# 2022-02-24      3            3     3         3
# 2022-02-25      5            5     5         5
# 2022-02-26      3            3     3         3
# 2022-02-27      2            2     2         2
# 2022-02-28      7            7     7         7
# 2022-03-01      6            6     6         6
# 2022-03-02      3            3     3         3
# 2022-03-03      2            2     2         2
# 2022-03-04      3            3     3         3
# 2022-03-05      2            2     2         2
# 2022-03-07      1            1     1         1
# 2022-03-08      6            6     6         6
# 2022-03-09      5            5     5         5
# 2022-03-10      3            3     3         3

# %%
#Plot the number of articles on each day
plt.figure(figsize =(15,10))
ax = sns.barplot( x = daily_data.index , y = daily_data['title'])
ax.set(xlabel = 'Published Date', ylabel = 'Number of Description of news', title = 'Bitcoin News')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)
plt.savefig('../Group4/Images/bitcoin_articles.png')
plt.show()

# %% [markdown]
# ## Calculating VADER Sentiment Score for News Titles and Text

# %%
# Sentiment calculation based on compound score
def get_sentiment(score):
    """
    Calculates the sentiment based on the compound score.
    """
    result = 0  # Neutral by default
    if score >= 0.05:  # Positive
        result = 1
    elif score <= -0.05:  # Negative
        result = -1

    return result

# %%
# Sentiment scores dictionaries
title_sent = {
    "title_compound": [],
    "title_pos": [],
    "title_neu": [],
    "title_neg": [],
    "title_sent": [],
}
text_sent = {
    "text_compound": [],
    "text_pos": [],
    "text_neu": [],
    "text_neg": [],
    "text_sent": [],
}

# Get sentiment for the text and the title
for index, row in news_df.iterrows():
    try:
        # Sentiment scoring with VADER
        title_sentiment = analyzer.polarity_scores(row["title"])
        title_sent["title_compound"].append(title_sentiment["compound"])
        title_sent["title_pos"].append(title_sentiment["pos"])
        title_sent["title_neu"].append(title_sentiment["neu"])
        title_sent["title_neg"].append(title_sentiment["neg"])
        title_sent["title_sent"].append(get_sentiment(title_sentiment["compound"]))

        text_sentiment = analyzer.polarity_scores(row["text"])
        text_sent["text_compound"].append(text_sentiment["compound"])
        text_sent["text_pos"].append(text_sentiment["pos"])
        text_sent["text_neu"].append(text_sentiment["neu"])
        text_sent["text_neg"].append(text_sentiment["neg"])
        text_sent["text_sent"].append(get_sentiment(text_sentiment["compound"]))
    except AttributeError:
        pass

# Attaching sentiment columns to the News DataFrame
title_sentiment_df = pd.DataFrame(title_sent)
text_sentiment_df = pd.DataFrame(text_sent)
news_df = news_df.join(title_sentiment_df).join(text_sentiment_df)

news_df.head()
# Out:
#                                                title  \
# 0  Netflix is already making a docuseries about t...
# 1  Justice Dept. Announces Raft of Changes Meant ...
# 2  Inside Heather Morgan and Ilya Lichtenstein's ...
# 3  Super Bowl Crypto Ads Feature Larry David, LeB...
# 4  It Only Took 3 Days for Netflix to Order a Doc...
#
#                                          description  \
# 0  Netflix\r\n is making a docuseries about one o...
# 1  The moves came a week after the department mad...
# 2  The arrests of Ilya Lichtenstein and Heather M...
# 3  If Sunday’s Super Bowl ads are any indication,...
# 4  The news of one of the biggest money launderin...
#
#                                                 text        date language  \
# 0  Netflix\r\n is making a docuseries about one o...  2022-02-11       en
# 1  Even in cyberspace, the Department of Justice ...  2022-02-17       en
# 2  The couple would never flee from the country a...  2022-02-13       en
# 3  If Sundays Super Bowl ads are any indication, ...  2022-02-14       en
# 4  The news of one of the biggest money launderin...  2022-02-12       en
#
#    title_compound  title_pos  title_neu  title_neg  title_sent  text_compound  \
# 0          0.0000      0.000      1.000        0.0           0        -0.7096
# 1          0.5267      0.274      0.726        0.0           1         0.7351
# 2          0.0000      0.000      1.000        0.0           0        -0.3400
# 3          0.8020      0.356      0.644        0.0           1         0.7783
# 4          0.0000      0.000      1.000        0.0           0         0.5859
#
#    text_pos  text_neu  text_neg  text_sent
# 0     0.000     0.831     0.169         -1
# 1     0.147     0.853     0.000          1
# 2     0.057     0.825     0.118         -1
# 3     0.163     0.837     0.000          1
# 4     0.124     0.876     0.000          1

# %% [markdown]
# ## Analyzing Sentiments Results

# %%
# Plot bar chart
news_df.plot(
    y=["title_sent", "text_sent"],
    kind="bar",
    title="News Title and Text Sentiment Comparisson",
    figsize=(10, 8),
    grid=True,
)
# Out:
# <AxesSubplot:title={'center':'News Title and Text Sentiment Comparisson'}>

# %%
#Grouping the data by date and finding the avg title sentiment compound score on that day
title_sentiment_avg = news_df.groupby('date')[['title_compound']].mean()

# %%
#Plot the title compound scores according to the dates
plt.figure(figsize =(10,10))
plt.xticks(rotation=45)
sns.lineplot(x = title_sentiment_avg.index, y = title_sentiment_avg['title_compound']).set_title('Bitcoin Average Title Compound through Vader Sentiment')
plt.savefig('../Group4/Images/bitcoin_vader.png')
plt.show()

# %%
# Describe dataframe
news_df.describe()
# Out:
#        title_compound   title_pos  title_neu   title_neg  title_sent  \
# count      100.000000  100.000000  100.00000  100.000000  100.000000
# mean         0.034665    0.088920    0.83949    0.071580    0.040000
# std          0.359265    0.138495    0.16926    0.120728    0.751026
# min         -0.750600    0.000000    0.41700    0.000000   -1.000000
# 25%         -0.109025    0.000000    0.72300    0.000000   -1.000000
# 50%          0.000000    0.000000    0.84450    0.000000    0.000000
# 75%          0.249425    0.172500    1.00000    0.167000    1.000000
# max          0.802000    0.559000    1.00000    0.444000    1.000000
#
#        text_compound    text_pos    text_neu    text_neg   text_sent
# count     100.000000  100.000000  100.000000  100.000000  100.000000
# mean        0.021806    0.069990    0.869460    0.060570    0.020000
# std         0.474368    0.067578    0.087923    0.073272    0.942595
# min        -0.895700    0.000000    0.627000    0.000000   -1.000000
# 25%        -0.323650    0.000000    0.821250    0.000000   -1.000000
# 50%         0.000000    0.058000    0.874500    0.041000    0.000000
# 75%         0.428550    0.108500    0.938250    0.096000    1.000000
# max         0.907900    0.292000    1.000000    0.269000    1.000000

# %% [markdown]
# ## Bitcoin Crypto price

# %%
#Getting Crypto price of Bitcoin from Yahoo Finance
bit_df = yf.download('BTC-USD', 
                      start='2022-02-10', 
                      end='2022-03-10', 
                      progress=False,
)
bit_df.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2022-02-10  44347.800781  45661.171875  43402.808594  43565.113281
# 2022-02-11  43571.128906  43810.832031  42114.539062  42407.937500
# 2022-02-12  42412.300781  42992.550781  41852.574219  42244.468750
# 2022-02-13  42236.566406  42693.054688  41950.941406  42197.515625
# 2022-02-14  42157.398438  42775.777344  41681.957031  42586.917969
#
#                Adj Close       Volume
# Date
# 2022-02-10  43565.113281  32142048537
# 2022-02-11  42407.937500  26954925781
# 2022-02-12  42244.468750  18152390304
# 2022-02-13  42197.515625  14741589015
# 2022-02-14  42586.917969  20827783012

# %%
#Plotting the closing prices
bit_df['Close'].plot(label = 'Closing Price', figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Merging Bitcoin Price with Sentiment Data

# %%
#Extracting the sentiment result from the News DF
news_df_edit = news_df.drop(columns=["title", "description", "text", "language"])
news_df_edit.head()
# Out:
#          date  title_compound  title_pos  title_neu  title_neg  title_sent  \
# 0  2022-02-11          0.0000      0.000      1.000        0.0           0
# 1  2022-02-17          0.5267      0.274      0.726        0.0           1
# 2  2022-02-13          0.0000      0.000      1.000        0.0           0
# 3  2022-02-14          0.8020      0.356      0.644        0.0           1
# 4  2022-02-12          0.0000      0.000      1.000        0.0           0
#
#    text_compound  text_pos  text_neu  text_neg  text_sent
# 0        -0.7096     0.000     0.831     0.169         -1
# 1         0.7351     0.147     0.853     0.000          1
# 2        -0.3400     0.057     0.825     0.118         -1
# 3         0.7783     0.163     0.837     0.000          1
# 4         0.5859     0.124     0.876     0.000          1

# %%
#Parsing date to date time format
news_df_edit["date"] = pd.to_datetime(news_df_edit["date"])
print(news_df_edit.dtypes)
# Out:
# date              datetime64[ns]
# title_compound           float64
# title_pos                float64
# title_neu                float64
# title_neg                float64
# title_sent                 int64
# text_compound            float64
# text_pos                 float64
# text_neu                 float64
# text_neg                 float64
# text_sent                  int64
# dtype: object

# %%
#Sorting Values by Date
news_df_edit.sort_values(by='date', inplace=True)
print(news_df_edit)
# Out:
#          date  title_compound  title_pos  title_neu  title_neg  title_sent  \
# 65 2022-02-10          0.0000      0.000      1.000      0.000           0
# 70 2022-02-10         -0.4939      0.000      0.802      0.198          -1
# 6  2022-02-10          0.2023      0.205      0.795      0.000           1
# 88 2022-02-10         -0.7506      0.000      0.556      0.444          -1
# 0  2022-02-11          0.0000      0.000      1.000      0.000           0
# ..        ...             ...        ...        ...        ...         ...
# 42 2022-03-09         -0.4215      0.000      0.781      0.219          -1
# 69 2022-03-09          0.0000      0.000      1.000      0.000           0
# 24 2022-03-10          0.1531      0.151      0.849      0.000           1
# 93 2022-03-10         -0.6124      0.000      0.643      0.357          -1
# 33 2022-03-10          0.0000      0.000      1.000      0.000           0
#
#     text_compound  text_pos  text_neu  text_neg  text_sent
# 65         0.0000     0.000     1.000     0.000          0
# 70         0.0000     0.000     1.000     0.000          0
# 6         -0.2023     0.039     0.899     0.062         -1
# 88        -0.5859     0.124     0.659     0.217         -1
# 0         -0.7096     0.000     0.831     0.169         -1
# ..            ...       ...       ...       ...        ...
# 42        -0.2500     0.059     0.850     0.092         -1
# 69         0.5267     0.108     0.892     0.000          1
# 24         0.4215     0.091     0.909     0.000          1
# 93        -0.4019     0.079     0.765     0.156         -1
# 33        -0.2500     0.065     0.807     0.127         -1
#
# [100 rows x 11 columns]

# %%
#Grouping all the title sentiment of the same date into the min value of that date - Conservative Approach to ensure we are not overestimating
news_df_title = news_df_edit.groupby('date', as_index=False, sort=False)['title_sent'].min()
news_df_title
# Out:
#          date  title_sent
# 0  2022-02-10          -1
# 1  2022-02-11          -1
# 2  2022-02-12           0
# 3  2022-02-13          -1
# 4  2022-02-14          -1
# 5  2022-02-15          -1
# 6  2022-02-16           1
# 7  2022-02-17          -1
# 8  2022-02-18          -1
# 9  2022-02-19          -1
# 10 2022-02-20           1
# 11 2022-02-21           0
# 12 2022-02-22          -1
# 13 2022-02-23           1
# 14 2022-02-24          -1
# 15 2022-02-25           0
# 16 2022-02-26           0
# 17 2022-02-27           0
# 18 2022-02-28          -1
# 19 2022-03-01           0
# 20 2022-03-02           0
# 21 2022-03-03           0
# 22 2022-03-04          -1
# 23 2022-03-05           0
# 24 2022-03-07          -1
# 25 2022-03-08          -1
# 26 2022-03-09          -1
# 27 2022-03-10          -1

# %%
#Grouping all the text sentiment of the same date into the min value of that date - Conservative Approach to ensure we are not overestimating
news_df_text = news_df_edit.groupby('date', as_index=False, sort=False)['text_sent'].min()
news_df_text
# Out:
#          date  text_sent
# 0  2022-02-10         -1
# 1  2022-02-11         -1
# 2  2022-02-12         -1
# 3  2022-02-13         -1
# 4  2022-02-14         -1
# 5  2022-02-15         -1
# 6  2022-02-16         -1
# 7  2022-02-17         -1
# 8  2022-02-18         -1
# 9  2022-02-19          1
# 10 2022-02-20          1
# 11 2022-02-21          0
# 12 2022-02-22         -1
# 13 2022-02-23          1
# 14 2022-02-24         -1
# 15 2022-02-25         -1
# 16 2022-02-26         -1
# 17 2022-02-27          0
# 18 2022-02-28         -1
# 19 2022-03-01         -1
# 20 2022-03-02         -1
# 21 2022-03-03          0
# 22 2022-03-04         -1
# 23 2022-03-05         -1
# 24 2022-03-07         -1
# 25 2022-03-08         -1
# 26 2022-03-09         -1
# 27 2022-03-10         -1

# %%
#Renaming the column to Date which is same as crypto column and indexing the DF by date
news_df_title = news_df_title.rename(columns={'date': 'Date'})
news_df_title.set_index('Date', inplace=True)
news_df_title.head()
# Out:
#             title_sent
# Date
# 2022-02-10          -1
# 2022-02-11          -1
# 2022-02-12           0
# 2022-02-13          -1
# 2022-02-14          -1

# %%
#Renaming the column to Date which is same as crypto column and indexing the DF by date
news_df_text = news_df_text.rename(columns={'date': 'Date'})
news_df_text.set_index('Date', inplace=True)
news_df_text.head()
# Out:
#             text_sent
# Date
# 2022-02-10         -1
# 2022-02-11         -1
# 2022-02-12         -1
# 2022-02-13         -1
# 2022-02-14         -1

# %%
#Concat the crypto price with sentiment data
sentiment_closing_df = pd.concat([news_df_title,news_df_text,bit_df], axis=1)
sentiment_closing_df.head()
# Out:
#             title_sent  text_sent          Open          High           Low  \
# Date
# 2022-02-10        -1.0       -1.0  44347.800781  45661.171875  43402.808594
# 2022-02-11        -1.0       -1.0  43571.128906  43810.832031  42114.539062
# 2022-02-12         0.0       -1.0  42412.300781  42992.550781  41852.574219
# 2022-02-13        -1.0       -1.0  42236.566406  42693.054688  41950.941406
# 2022-02-14        -1.0       -1.0  42157.398438  42775.777344  41681.957031
#
#                    Close     Adj Close       Volume
# Date
# 2022-02-10  43565.113281  43565.113281  32142048537
# 2022-02-11  42407.937500  42407.937500  26954925781
# 2022-02-12  42244.468750  42244.468750  18152390304
# 2022-02-13  42197.515625  42197.515625  14741589015
# 2022-02-14  42586.917969  42586.917969  20827783012

# %%
#Filling in empty values of title_sent with their most recent value positions - This is done when news is missing for any particular date
sentiment_closing_df['title_sent'] = sentiment_closing_df['title_sent'].fillna(method='ffill')
sentiment_closing_df.head()
# Out:
#             title_sent  text_sent          Open          High           Low  \
# Date
# 2022-02-10        -1.0       -1.0  44347.800781  45661.171875  43402.808594
# 2022-02-11        -1.0       -1.0  43571.128906  43810.832031  42114.539062
# 2022-02-12         0.0       -1.0  42412.300781  42992.550781  41852.574219
# 2022-02-13        -1.0       -1.0  42236.566406  42693.054688  41950.941406
# 2022-02-14        -1.0       -1.0  42157.398438  42775.777344  41681.957031
#
#                    Close     Adj Close       Volume
# Date
# 2022-02-10  43565.113281  43565.113281  32142048537
# 2022-02-11  42407.937500  42407.937500  26954925781
# 2022-02-12  42244.468750  42244.468750  18152390304
# 2022-02-13  42197.515625  42197.515625  14741589015
# 2022-02-14  42586.917969  42586.917969  20827783012

# %%
#Filling in empty values of text_sent with their most recent value positions - This is done when news is missing for any particular date
sentiment_closing_df['text_sent'] = sentiment_closing_df['text_sent'].fillna(method='ffill')
sentiment_closing_df.head()
# Out:
#             title_sent  text_sent          Open          High           Low  \
# Date
# 2022-02-10        -1.0       -1.0  44347.800781  45661.171875  43402.808594
# 2022-02-11        -1.0       -1.0  43571.128906  43810.832031  42114.539062
# 2022-02-12         0.0       -1.0  42412.300781  42992.550781  41852.574219
# 2022-02-13        -1.0       -1.0  42236.566406  42693.054688  41950.941406
# 2022-02-14        -1.0       -1.0  42157.398438  42775.777344  41681.957031
#
#                    Close     Adj Close       Volume
# Date
# 2022-02-10  43565.113281  43565.113281  32142048537
# 2022-02-11  42407.937500  42407.937500  26954925781
# 2022-02-12  42244.468750  42244.468750  18152390304
# 2022-02-13  42197.515625  42197.515625  14741589015
# 2022-02-14  42586.917969  42586.917969  20827783012

# %%
#Save tha final DataFrame as a CSV file for further analysis in the forthcoming activities.
file_path = Path("sentiment_closing_bit.csv")
sentiment_closing_df.to_csv(file_path, index=True, encoding='utf-8-sig')

# %%
# Sorting title_sent into Positive, Negative and Neutral sentiment

sentiment = [] 
for score in sentiment_closing_df['title_sent']:
    if score >= 1 :
          sentiment.append("Positive") 
    elif score <= - 1 : 
          sentiment.append("Negative")        
    else : 
        sentiment.append("Neutral")   

sentiment_closing_df["Title_Sentiment"] = sentiment
sentiment_closing_df.head()
# Out:
#             title_sent  text_sent          Open          High           Low  \
# Date
# 2022-02-10        -1.0       -1.0  44347.800781  45661.171875  43402.808594
# 2022-02-11        -1.0       -1.0  43571.128906  43810.832031  42114.539062
# 2022-02-12         0.0       -1.0  42412.300781  42992.550781  41852.574219
# 2022-02-13        -1.0       -1.0  42236.566406  42693.054688  41950.941406
# 2022-02-14        -1.0       -1.0  42157.398438  42775.777344  41681.957031
#
#                    Close     Adj Close       Volume Title_Sentiment
# Date
# 2022-02-10  43565.113281  43565.113281  32142048537        Negative
# 2022-02-11  42407.937500  42407.937500  26954925781        Negative
# 2022-02-12  42244.468750  42244.468750  18152390304         Neutral
# 2022-02-13  42197.515625  42197.515625  14741589015        Negative
# 2022-02-14  42586.917969  42586.917969  20827783012        Negative

# %%
# Sentiment Count
sentiment_closing_df['Title_Sentiment'].value_counts()
# Out:
# Negative    16
# Neutral     10
# Positive     3
# Name: Title_Sentiment, dtype: int64

# %%
# Sentiment Plot
sentiment_closing_df['Title_Sentiment'].value_counts().plot.bar(title = 'Bitcoin Title Sentiment Classification', figsize = (20,10))
# Out:
# <AxesSubplot:title={'center':'Bitcoin Title Sentiment Classification'}>

# %%
#Crypto Price trend basis the difference between current price to previous day price and coverting them to '0'
sentiment_closing_df['Price Diff'] = sentiment_closing_df['Close'].diff()
sentiment_closing_df.dropna(inplace = True)
sentiment_closing_df['Trend'] = np.where(
    sentiment_closing_df['Price Diff'] > 0 , 1, 0)

sentiment_closing_df.head()
# Out:
#             title_sent  text_sent          Open          High           Low  \
# Date
# 2022-02-11        -1.0       -1.0  43571.128906  43810.832031  42114.539062
# 2022-02-12         0.0       -1.0  42412.300781  42992.550781  41852.574219
# 2022-02-13        -1.0       -1.0  42236.566406  42693.054688  41950.941406
# 2022-02-14        -1.0       -1.0  42157.398438  42775.777344  41681.957031
# 2022-02-15        -1.0       -1.0  42586.464844  44667.218750  42491.035156
#
#                    Close     Adj Close       Volume Title_Sentiment  \
# Date
# 2022-02-11  42407.937500  42407.937500  26954925781        Negative
# 2022-02-12  42244.468750  42244.468750  18152390304         Neutral
# 2022-02-13  42197.515625  42197.515625  14741589015        Negative
# 2022-02-14  42586.917969  42586.917969  20827783012        Negative
# 2022-02-15  44575.203125  44575.203125  22721659051        Negative
#
#              Price Diff  Trend
# Date
# 2022-02-11 -1157.175781      0
# 2022-02-12  -163.468750      0
# 2022-02-13   -46.953125      0
# 2022-02-14   389.402344      1
# 2022-02-15  1988.285156      1

# %%
## Calculating the days of price trend where price did not increase
sentiment_closing_df.loc[sentiment_closing_df.Trend == 0,"Trend"].count()
# Out:
# 17

# %%
## Calculating the days of price trend where price did increase
sentiment_closing_df.loc[sentiment_closing_df.Trend == 1,"Trend"].count()
# Out:
# 11

# %%
# Binary encoding Sentiment column
bit_trend = sentiment_closing_df[["Close", "Volume", "Title_Sentiment", "Trend"]]
bit_trend = pd.get_dummies(bit_trend, columns=["Title_Sentiment"])
bit_trend.head()
# Out:
#                    Close       Volume  Trend  Title_Sentiment_Negative  \
# Date
# 2022-02-11  42407.937500  26954925781      0                         1
# 2022-02-12  42244.468750  18152390304      0                         0
# 2022-02-13  42197.515625  14741589015      0                         1
# 2022-02-14  42586.917969  20827783012      1                         1
# 2022-02-15  44575.203125  22721659051      1                         1
#
#             Title_Sentiment_Neutral  Title_Sentiment_Positive
# Date
# 2022-02-11                        0                         0
# 2022-02-12                        1                         0
# 2022-02-13                        0                         0
# 2022-02-14                        0                         0
# 2022-02-15                        0                         0

# %%
#Save tha final DataFrame as a CSV file for further analysis in the forthcoming activities.
file_path = Path("bit_trend.csv")
bit_trend.to_csv(file_path, index=True, encoding='utf-8-sig')

# %% [markdown]
# ## Calculating the Correlation of Title Compound Avg with Daily Close Price & Daily Returns

# %%
#Ploting the title_sent with Trend of closing prices
sns.set(rc={'figure.figsize':(13.0,8.0)})
ax=sns.lineplot(data=sentiment_closing_df['Trend'], color="b",label='Price Trend')
ax2 = plt.twinx()
sns.lineplot(data=sentiment_closing_df["title_sent"], color="g", ax=ax2, label='Title sentiment')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='title_sent'>

# %%
#Grouping all the title compound of the same date into the avg value of that date 
title_compound_avg = news_df_edit.groupby('date', as_index=False, sort=False)['title_compound'].mean()

#Renaming the column to Date which is same as crypto column and indexing the DF by date 
title_compound_avg = title_compound_avg.rename(columns={'date': 'Date'})
title_compound_avg.set_index('Date', inplace=True)

#Concat the crypto price with sentiment data
title_closing_df = pd.concat([title_compound_avg,bit_df], axis=1)
title_closing_df.head()
# Out:
#             title_compound          Open          High           Low  \
# Date
# 2022-02-10       -0.260550  44347.800781  45661.171875  43402.808594
# 2022-02-11       -0.130383  43571.128906  43810.832031  42114.539062
# 2022-02-12        0.247667  42412.300781  42992.550781  41852.574219
# 2022-02-13       -0.025675  42236.566406  42693.054688  41950.941406
# 2022-02-14        0.258643  42157.398438  42775.777344  41681.957031
#
#                    Close     Adj Close       Volume
# Date
# 2022-02-10  43565.113281  43565.113281  32142048537
# 2022-02-11  42407.937500  42407.937500  26954925781
# 2022-02-12  42244.468750  42244.468750  18152390304
# 2022-02-13  42197.515625  42197.515625  14741589015
# 2022-02-14  42586.917969  42586.917969  20827783012

# %%
#Plotting the Title Compound Avg with closing prices
sns.set(rc={'figure.figsize':(10,10)})
ax=sns.lineplot(data=title_closing_df['title_compound'], color="b",label='Title compound sentiment score')
ax2 = plt.twinx()
sns.lineplot(data=title_closing_df["Close"], color="g", ax=ax2, label='Bitcoin Close Price').set_title('Bitcoin Closing Price and Title News Sentiment')
plt.savefig('../Group4/Images/bitcoin_closing.png')

# %%
# Use the drop function to drop extra columns
bit_close = title_closing_df.drop(columns=["title_compound", "Open", "High", "Low", "Adj Close", "Volume"])

# Display sample data
bit_close.head()
# Out:
#                    Close
# Date
# 2022-02-10  43565.113281
# 2022-02-11  42407.937500
# 2022-02-12  42244.468750
# 2022-02-13  42197.515625
# 2022-02-14  42586.917969

# %%
# Use the `pct_change` function to calculate daily returns of Bitcoin
bit_returns = bit_close.pct_change().dropna()

# Display sample data
bit_returns.head()
# Out:
#                Close
# Date
# 2022-02-11 -0.026562
# 2022-02-12 -0.003855
# 2022-02-13 -0.001111
# 2022-02-14  0.009228
# 2022-02-15  0.046688

# %%
# Use the drop function to drop extra columns
sentiment_close = title_closing_df.drop(columns=["Open", "High", "Low", "Close", "Adj Close", "Volume"])

# %%
# Merge Title compound from sentiment with Doge daily returns
topic_sentiments = bit_returns.join(sentiment_close).dropna(how="any")

# Display data
display(topic_sentiments)
# Out:
#                Close  title_compound
# Date
# 2022-02-11 -0.026562       -0.130383
# 2022-02-12 -0.003855        0.247667
# 2022-02-13 -0.001111       -0.025675
# 2022-02-14  0.009228        0.258643
# 2022-02-15  0.046688        0.037643
# 2022-02-16 -0.013760        0.381800
# 2022-02-17 -0.077882        0.004680
# 2022-02-18 -0.012508       -0.015880
# 2022-02-19  0.002278       -0.361200
# 2022-02-20 -0.042141        0.318200
# 2022-02-21 -0.035286        0.000000
# 2022-02-22  0.032656       -0.225033
# 2022-02-23 -0.025844        0.421500
# 2022-02-24  0.027778        0.061833
# 2022-02-25  0.022999        0.239700
# 2022-02-26 -0.002781        0.216200
# 2022-02-27 -0.035682        0.113150
# 2022-02-28  0.145412       -0.146514
# 2022-03-01  0.026889        0.159050
# 2022-03-02 -0.009706        0.324833
# 2022-03-03 -0.033520        0.318450
# 2022-03-04 -0.078069       -0.327067
# 2022-03-05  0.006719        0.000000
# 2022-03-07 -0.009317       -0.128000
# 2022-03-08  0.017740        0.084267
# 2022-03-09  0.083786       -0.037720
# 2022-03-10 -0.060631       -0.153100

# %%
# Correlate the Title Compound Avg to Daily returns
topic_sentiments.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_77a4f_row0_col0, #T_77a4f_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_77a4f_row0_col1, #T_77a4f_row1_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_77a4f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Close</th>
#       <th class="col_heading level0 col1" >title_compound</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77a4f_level0_row0" class="row_heading level0 row0" >Close</th>
#       <td id="T_77a4f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_77a4f_row0_col1" class="data row0 col1" >-0.085909</td>
#     </tr>
#     <tr>
#       <th id="T_77a4f_level0_row1" class="row_heading level0 row1" >title_compound</th>
#       <td id="T_77a4f_row1_col0" class="data row1 col0" >-0.085909</td>
#       <td id="T_77a4f_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Use the drop function to drop extra columns
title_and_close = title_closing_df.drop(columns=["Open", "High", "Low", "Adj Close", "Volume"])

# Display sample data
title_and_close.head()
# Out:
#             title_compound         Close
# Date
# 2022-02-10       -0.260550  43565.113281
# 2022-02-11       -0.130383  42407.937500
# 2022-02-12        0.247667  42244.468750
# 2022-02-13       -0.025675  42197.515625
# 2022-02-14        0.258643  42586.917969

# %%
# Correlate the Title Compound Avg to Closing Price
title_and_close.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_fdb7d_row0_col0, #T_fdb7d_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_fdb7d_row0_col1, #T_fdb7d_row1_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_fdb7d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >title_compound</th>
#       <th class="col_heading level0 col1" >Close</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fdb7d_level0_row0" class="row_heading level0 row0" >title_compound</th>
#       <td id="T_fdb7d_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_fdb7d_row0_col1" class="data row0 col1" >0.099111</td>
#     </tr>
#     <tr>
#       <th id="T_fdb7d_level0_row1" class="row_heading level0 row1" >Close</th>
#       <td id="T_fdb7d_row1_col0" class="data row1 col0" >0.099111</td>
#       <td id="T_fdb7d_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Check Correlation between Title_sent and close
# Use the drop function to drop extra columns
title_and_close1 = sentiment_closing_df.drop(columns=["Open", "text_sent", "Title_Sentiment", "Price Diff", "Trend", "High", "Low", "Adj Close", "Volume"])

# Display sample data
title_and_close1.head()
# Out:
#             title_sent         Close
# Date
# 2022-02-11        -1.0  42407.937500
# 2022-02-12         0.0  42244.468750
# 2022-02-13        -1.0  42197.515625
# 2022-02-14        -1.0  42586.917969
# 2022-02-15        -1.0  44575.203125

# %%
# Correlate the Title Sentiment to Closing Price
title_and_close1.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_70699_row0_col0, #T_70699_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_70699_row0_col1, #T_70699_row1_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_70699_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >title_sent</th>
#       <th class="col_heading level0 col1" >Close</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70699_level0_row0" class="row_heading level0 row0" >title_sent</th>
#       <td id="T_70699_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_70699_row0_col1" class="data row0 col1" >-0.098122</td>
#     </tr>
#     <tr>
#       <th id="T_70699_level0_row1" class="row_heading level0 row1" >Close</th>
#       <td id="T_70699_row1_col0" class="data row1 col0" >-0.098122</td>
#       <td id="T_70699_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
